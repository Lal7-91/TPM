# %%
from serpapi import GoogleSearch
import json
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
params = {
    "engine": "google_hotels",
    "q": "Riyadh hotels",
    "check_in_date": "2025-10-13",
    "check_out_date": "2025-10-14",
    "adults": "2",
    "sort_by": "8",
    "max_price": "500",
    "currency": "SAR",
    "gl": "us",
    "hl": "en",
    "api_key": os.environ.get("SERPAPI_KEY")
}

search = GoogleSearch(params)
results = search.get_dict()

with open("test.json", "w") as f:
    json.dump(results, f, indent=2)

# %%
print(results.keys())
# Out:
# dict_keys(['search_metadata', 'search_parameters', 'search_information', 'brands', 'properties', 'serpapi_pagination'])

# %%
# print properties names and prices

for hotel in results.get("properties", []):
    name = hotel.get("name")
    price = hotel.get("total_rate", {}).get("extracted_lowest")
    print(f"\nName: {name} \n Total: {price} SAR")
# Out:
# Name: OVAZ
#  Total: 421 SAR
#
# Name: فشركة سند للاستقدام ندق مارفوليوس
#  Total: 251 SAR
#
# Name: Seven Gardens Hotel
#  Total: 474 SAR
#
# Name: فندق وادي هليز | Al Wadi Hills Hotel
#  Total: 348 SAR
#
# Name: توارن الروابي
#  Total: 230 SAR
#
# Name: بيستانا للشقق الفندقيه 4
#  Total: 354 SAR
#
# Name: Wasan Suites اجنحة وسن
#  Total: 247 SAR
#
# Name: افال للشقق المخدومة-اليرموك
#  Total: 313 SAR
#
# Name: شقق نيام للشقق المخدومة اقتصادي
#  Total: 279 SAR
#
# Name: Rosa Grand Hotel
#  Total: 494 SAR
#
# Name: Liora Hotel Al Yasmin
#  Total: 568 SAR
#
# Name: فندق مودرست Modrest Hotel
#  Total: 572 SAR
#
# Name: Namar Home Serviced Suites
#  Total: 253 SAR
#
# Name: فندق هوم ليا للشقق الفندقية
#  Total: 360 SAR
#
# Name: Dorra Suites أجنحة درة
#  Total: 517 SAR
#
# Name: Shorfa Hotel
#  Total: 465 SAR
#
# Name: Hayat Alriyadh Hotel
#  Total: 324 SAR
#
# Name: فندق ريان الجنادرية للشقق المخدومة
#  Total: 278 SAR
